# %% [raw]
# Name : Shubham Rajesh Dhanwat
#
# Class : TE Computer
#
# Div : B
#
# Roll No : 18
#
# Lab Assignment 2
#
# Build training and testing dataset of assignment 1 to predict the probability of a survival of a person based on gender,
# age and passenger-class.

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
ds=sns.load_dataset('titanic')

# %%
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ds.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
len(ds)
# Out:
# 891

# %%
ds['age']=ds['age'].fillna(ds['age'].median())
#data cleaning

x = ds['age']  #input
y = ds['survived'] #output

# %%
x = x.values.reshape(-1,1)
x.shape
# Out:
# (891, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = 0,test_size=0.25)

# %% [raw]
# build train and test

# %%
len(x_train)
# Out:
# 668

# %%
len(x_test)
# Out:
# 223

# %%
from collections import Counter

# %%
Counter(y)
# Out:
# Counter({0: 549, 1: 342})

# %%
sns.countplot(x=y)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
from sklearn.naive_bayes import GaussianNB

# %% [raw]
# GaussianNewbase classfier which uses normally distributed data uses to built probability baesed model and do the prediction based on probabilities.
# // input data should be in two dimentions for GaussianNewbase method

# %%
model = GaussianNB()

# %% [raw]
# model is the object of  GaussianNB class
# #train the algoritnm with given training data

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict_proba(x_test)

# %%
y_pred
# Out:
# array([[0.62876821, 0.37123179],
#        [0.62876821, 0.37123179],
#        [0.51657653, 0.48342347],
#        [0.62876821, 0.37123179],
#        [0.63148867, 0.36851133],
#        [0.62876821, 0.37123179],
#        [0.64689984, 0.35310016],
#        [0.63625703, 0.36374297],
#        [0.6192395 , 0.3807605 ],
#        [0.62876821, 0.37123179],
#        [0.62264556, 0.37735444],
#        [0.64689984, 0.35310016],
#        [0.62876821, 0.37123179],
#        [0.51657653, 0.48342347],
#        [0.61560095, 0.38439905],
#        [0.56600603, 0.43399397],
#        [0.61172787, 0.38827213],
#        [0.59385049, 0.40614951],
#        [0.64314813, 0.35685187],
#        [0.45943048, 0.54056952],
#        [0.58877545, 0.41122455],
#        [0.60761825, 0.39238175],
#        [0.62876821, 0.37123179],
#        [0.62876821, 0.37123179],
#        [0.60761825, 0.39238175],
#        [0.64689984, 0.35310016],
#        [0.63830829, 0.36169171],
#        [0.60761825, 0.39238175],
# ...

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 65.47085201793722

# %%
x = ds['pclass'].values
y = ds['survived']
x = x.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = 0,test_size=0.25)

# %%
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.predict_proba(x_test)
# Out:
# array([[0.7559945 , 0.2440055 ],
#        [0.7559945 , 0.2440055 ],
#        [0.7559945 , 0.2440055 ],
#        [0.29957107, 0.70042893],
#        [0.7559945 , 0.2440055 ],
#        [0.29957107, 0.70042893],
#        [0.29957107, 0.70042893],
#        [0.29957107, 0.70042893],
#        [0.29957107, 0.70042893],
#        [0.7559945 , 0.2440055 ],
#        [0.7559945 , 0.2440055 ],
#        [0.58864036, 0.41135964],
#        [0.7559945 , 0.2440055 ],
#        [0.58864036, 0.41135964],
#        [0.29957107, 0.70042893],
#        [0.7559945 , 0.2440055 ],
#        [0.7559945 , 0.2440055 ],
#        [0.58864036, 0.41135964],
#        [0.7559945 , 0.2440055 ],
#        [0.7559945 , 0.2440055 ],
#        [0.58864036, 0.41135964],
#        [0.29957107, 0.70042893],
#        [0.7559945 , 0.2440055 ],
#        [0.29957107, 0.70042893],
#        [0.7559945 , 0.2440055 ],
#        [0.29957107, 0.70042893],
#        [0.7559945 , 0.2440055 ],
#        [0.7559945 , 0.2440055 ],
# ...

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 70.85201793721974

# %%
x = ds['sex']
y = ds['survived']

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
x=enc.fit_transform(x)

# %%
x= x.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = 0,test_size=0.25)

# %%
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.predict_proba(x_test)
# Out:
# array([[0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.11021564, 0.88978436],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
#        [0.11021564, 0.88978436],
#        [0.84832829, 0.15167171],
#        [0.11021564, 0.88978436],
# ...

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 78.02690582959642
